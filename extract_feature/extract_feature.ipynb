# %%
import sys
import numpy
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torch.backends.cudnn as cudnn
from collections import OrderedDict
try:
    from . SpatialCrossMapLRN_temp import SpatialCrossMapLRN_temp
except:
    from SpatialCrossMapLRN_temp import SpatialCrossMapLRN_temp
import os
import time

import pathlib
containing_dir = str(pathlib.Path(os.getcwd()).resolve().parent)


class LambdaBase(nn.Sequential):
    def __init__(self, fn, *args):
        super(LambdaBase, self).__init__(*args)
        self.lambda_func = fn

    def forward_prepare(self, input):
        output = []
        for module in self._modules.values():
            output.append(module(input))
        return output if output else input


class Lambda(LambdaBase):
    def forward(self, input):
        return self.lambda_func(self.forward_prepare(input))


#
def Conv2d(in_dim, out_dim, kernel, stride, padding):
    l = torch.nn.Conv2d(in_dim, out_dim, kernel, stride=stride, padding=padding)
    return l

def BatchNorm(dim):
    l = torch.nn.BatchNorm2d(dim)
    return l

def CrossMapLRN(size, alpha, beta, k=1.0, gpuDevice=0):
    lrn = SpatialCrossMapLRN_temp(size, alpha, beta, k, gpuDevice=gpuDevice)
    n = Lambda( lambda x,lrn=lrn: Variable(lrn.forward(x.data).cuda(gpuDevice)) if x.data.is_cuda else Variable(lrn.forward(x.data)) )
    return n

def Linear(in_dim, out_dim):
    l = torch.nn.Linear(in_dim, out_dim)
    return l


class Inception(nn.Module):
    def __init__(self, inputSize, kernelSize, kernelStride, outputSize, reduceSize, pool, useBatchNorm, reduceStride=None, padding=True):
        super(Inception, self).__init__()
        #
        self.seq_list = []
        self.outputSize = outputSize

        #
        # 1x1 conv (reduce) -> 3x3 conv
        # 1x1 conv (reduce) -> 5x5 conv
        # ...
        for i in range(len(kernelSize)):
            od = OrderedDict()
            # 1x1 conv
            od['1_conv'] = Conv2d(inputSize, reduceSize[i], (1, 1), reduceStride[i] if reduceStride is not None else 1, (0,0))
            if useBatchNorm:
                od['2_bn'] = BatchNorm(reduceSize[i])
            od['3_relu'] = nn.ReLU()
            # nxn conv
            pad = int(numpy.floor(kernelSize[i] / 2)) if padding else 0
            od['4_conv'] = Conv2d(reduceSize[i], outputSize[i], kernelSize[i], kernelStride[i], pad)
            if useBatchNorm:
                od['5_bn'] = BatchNorm(outputSize[i])
            od['6_relu'] = nn.ReLU()
            #
            self.seq_list.append(nn.Sequential(od))

        ii = len(kernelSize)
        # pool -> 1x1 conv
        od = OrderedDict()
        od['1_pool'] = pool
        if ii < len(reduceSize) and reduceSize[ii] is not None:
            i = ii
            od['2_conv'] = Conv2d(inputSize, reduceSize[i], (1,1), reduceStride[i] if reduceStride is not None else 1, (0,0))
            if useBatchNorm:
                od['3_bn'] = BatchNorm(reduceSize[i])
            od['4_relu'] = nn.ReLU()
        #
        self.seq_list.append(nn.Sequential(od))
        ii += 1

        # reduce: 1x1 conv (channel-wise pooling)
        if ii < len(reduceSize) and reduceSize[ii] is not None:
            i = ii
            od = OrderedDict()
            od['1_conv'] = Conv2d(inputSize, reduceSize[i], (1,1), reduceStride[i] if reduceStride is not None else 1, (0,0))
            if useBatchNorm:
                od['2_bn'] = BatchNorm(reduceSize[i])
            od['3_relu'] = nn.ReLU()
            self.seq_list.append(nn.Sequential(od))

        self.seq_list = nn.ModuleList(self.seq_list)


    def forward(self, input):
        x = input

        ys = []
        target_size = None
        depth_dim = 0
        for seq in self.seq_list:
            #print(seq)
            #print(self.outputSize)
            #print('x_size:', x.size())
            y = seq(x)
            y_size = y.size()
            #print('y_size:', y_size)
            ys.append(y)
            #
            if target_size is None:
                target_size = [0] * len(y_size)
            #
            for i in range(len(target_size)):
                target_size[i] = max(target_size[i], y_size[i])
            depth_dim += y_size[1]

        target_size[1] = depth_dim
        #print('target_size:', target_size)

        for i in range(len(ys)):
            y_size = ys[i].size()
            pad_l = int((target_size[3] - y_size[3]) // 2)
            pad_t = int((target_size[2] - y_size[2]) // 2)
            pad_r = target_size[3] - y_size[3] - pad_l
            pad_b = target_size[2] - y_size[2] - pad_t
            ys[i] = F.pad(ys[i], (pad_l, pad_r, pad_t, pad_b))

        output = torch.cat(ys, 1)

        return output


class netOpenFace(nn.Module):
    def __init__(self, useCuda, gpuDevice=0):
        super(netOpenFace, self).__init__()

        self.gpuDevice = gpuDevice

        self.layer1 = Conv2d(3, 64, (7,7), (2,2), (3,3))
        self.layer2 = BatchNorm(64)
        self.layer3 = nn.ReLU()
        self.layer4 = nn.MaxPool2d((3,3), stride=(2,2), padding=(1,1))
        self.layer5 = CrossMapLRN(5, 0.0001, 0.75, gpuDevice=gpuDevice)
        self.layer6 = Conv2d(64, 64, (1,1), (1,1), (0,0))
        self.layer7 = BatchNorm(64)
        self.layer8 = nn.ReLU()
        self.layer9 = Conv2d(64, 192, (3,3), (1,1), (1,1))
        self.layer10 = BatchNorm(192)
        self.layer11 = nn.ReLU()
        self.layer12 = CrossMapLRN(5, 0.0001, 0.75, gpuDevice=gpuDevice)
        self.layer13 = nn.MaxPool2d((3,3), stride=(2,2), padding=(1,1))
        self.layer14 = Inception(192, (3,5), (1,1), (128,32), (96,16,32,64), nn.MaxPool2d((3,3), stride=(2,2), padding=(0,0)), True)
        self.layer15 = Inception(256, (3,5), (1,1), (128,64), (96,32,64,64), nn.LPPool2d(2, (3,3), stride=(3,3)), True)
        self.layer16 = Inception(320, (3,5), (2,2), (256,64), (128,32,None,None), nn.MaxPool2d((3,3), stride=(2,2), padding=(0,0)), True)
        self.layer17 = Inception(640, (3,5), (1,1), (192,64), (96,32,128,256), nn.LPPool2d(2, (3,3), stride=(3,3)), True)
        self.layer18 = Inception(640, (3,5), (2,2), (256,128), (160,64,None,None), nn.MaxPool2d((3,3), stride=(2,2), padding=(0,0)), True)
        self.layer19 = Inception(1024, (3,), (1,), (384,), (96,96,256), nn.LPPool2d(2, (3,3), stride=(3,3)), True)
        self.layer21 = Inception(736, (3,), (1,), (384,), (96,96,256), nn.MaxPool2d((3,3), stride=(2,2), padding=(0,0)), True)
        self.layer22 = nn.AvgPool2d((3,3), stride=(1,1), padding=(0,0))
        self.layer25 = Linear(736, 128)

        #
        self.resize1 = nn.UpsamplingNearest2d(scale_factor=3)
        self.resize2 = nn.AvgPool2d(4)

        #
        # self.eval()

        if useCuda:
            self.cuda(gpuDevice)


    def forward(self, input):
        x = input

        if x.data.is_cuda and self.gpuDevice != 0:
            x = x.cuda(self.gpuDevice)

        #
        if x.size()[-1] == 128:
            x = self.resize2(self.resize1(x))

        x = self.layer8(self.layer7(self.layer6(self.layer5(self.layer4(self.layer3(self.layer2(self.layer1(x))))))))
        x = self.layer13(self.layer12(self.layer11(self.layer10(self.layer9(x)))))
        x = self.layer14(x)
        x = self.layer15(x)
        x = self.layer16(x)
        x = self.layer17(x)
        x = self.layer18(x)
        x = self.layer19(x)
        x = self.layer21(x)
        x = self.layer22(x)
        x = x.view((-1, 736))

        x_736 = x

        x = self.layer25(x)
        x_norm = torch.sqrt(torch.sum(x**2, 1) + 1e-6)
        x = torch.div(x, x_norm.view(-1, 1).expand_as(x))

        return (x, x_736)


def prepareOpenFace(useCuda=True, gpuDevice=0, useMultiGPU=False):
    model = netOpenFace(useCuda, gpuDevice)
    model.load_state_dict(torch.load(os.path.join(containing_dir, 'openface.pth')))

    if useMultiGPU:
        model = nn.DataParallel(model)

    return model

# %%
#extract feature and save

useCuda = True
if useCuda:
    assert torch.cuda.is_available()
else:
    assert False, 'Sorry, .pth file contains CUDA version of the network only.'

nof = prepareOpenFace()
nof = nof.eval()


import torchvision.transforms as transforms
import torchvision.datasets as dset

des_dir = "./celeba"
outf = "./celeba_embed/"
dataset = dset.ImageFolder(root=des_dir, transform=transforms.Compose([
                                            transforms.CenterCrop(224)
                                            transforms.Resize(96),
                                            transforms.ToTensor(),
                                            #transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                                 #std=[0.229, 0.224, 0.225])
                                            ]))

# %%
batchSize = 128
import torch.utils.data
dataloader = torch.utils.data.DataLoader(dataset,
                                         batch_size=batchSize,
                                         shuffle=False)

# %%
image_features = torch.FloatTensor(1, 736)
for i, data in enumerate(dataloader, 0):
    data, _ = data
    data = data.cuda()
    _, feature = nof(Variable(data))
    image_features = torch.cat((image_features, feature.data.cpu()), 0)
    print(image_features.shape)
# Out:
# torch.Size([129, 736])
# torch.Size([257, 736])
# torch.Size([385, 736])
# torch.Size([513, 736])
# torch.Size([641, 736])
# torch.Size([769, 736])
# torch.Size([897, 736])
# torch.Size([1025, 736])
# torch.Size([1153, 736])
# torch.Size([1281, 736])
# torch.Size([1409, 736])
# torch.Size([1537, 736])
# torch.Size([1665, 736])
# torch.Size([1793, 736])
# torch.Size([1921, 736])
# torch.Size([2049, 736])
# torch.Size([2177, 736])
# torch.Size([2305, 736])
# torch.Size([2433, 736])
# torch.Size([2561, 736])
# torch.Size([2689, 736])
# torch.Size([2817, 736])
# torch.Size([2945, 736])
# torch.Size([3073, 736])
# torch.Size([3201, 736])
# torch.Size([3329, 736])
# torch.Size([3457, 736])
# torch.Size([3585, 736])
# torch.Size([3713, 736])
# torch.Size([3841, 736])
# torch.Size([3969, 736])
# torch.Size([4097, 736])
# torch.Size([4225, 736])
# torch.Size([4353, 736])
# torch.Size([4481, 736])
# torch.Size([4609, 736])
# torch.Size([4737, 736])
# torch.Size([4865, 736])
# torch.Size([4993, 736])
# torch.Size([5121, 736])
# torch.Size([5249, 736])
# torch.Size([5377, 736])
# torch.Size([5505, 736])
# torch.Size([5633, 736])
# torch.Size([5761, 736])
# torch.Size([5889, 736])
# torch.Size([6017, 736])
# torch.Size([6145, 736])
# torch.Size([6273, 736])
# torch.Size([6401, 736])
# torch.Size([6529, 736])
# torch.Size([6657, 736])
# torch.Size([6785, 736])
# torch.Size([6913, 736])
# torch.Size([7041, 736])
# torch.Size([7169, 736])
# torch.Size([7297, 736])
# torch.Size([7425, 736])
# torch.Size([7553, 736])
# torch.Size([7681, 736])
# torch.Size([7809, 736])
# torch.Size([7937, 736])
# torch.Size([8065, 736])
# torch.Size([8193, 736])
# torch.Size([8321, 736])
# torch.Size([8449, 736])
# torch.Size([8577, 736])
# torch.Size([8705, 736])
# torch.Size([8833, 736])
# torch.Size([8961, 736])
# torch.Size([9089, 736])
# torch.Size([9217, 736])
# torch.Size([9345, 736])
# torch.Size([9473, 736])
# torch.Size([9601, 736])
# torch.Size([9729, 736])
# torch.Size([9857, 736])
# torch.Size([9985, 736])
# torch.Size([10113, 736])
# torch.Size([10241, 736])
# torch.Size([10369, 736])
# torch.Size([10497, 736])
# torch.Size([10625, 736])
# torch.Size([10753, 736])
# torch.Size([10881, 736])
# torch.Size([11009, 736])
# torch.Size([11137, 736])
# torch.Size([11265, 736])
# torch.Size([11393, 736])
# torch.Size([11521, 736])
# torch.Size([11649, 736])
# torch.Size([11777, 736])
# torch.Size([11905, 736])
# torch.Size([12033, 736])
# torch.Size([12161, 736])
# torch.Size([12289, 736])
# torch.Size([12417, 736])
# torch.Size([12545, 736])
# torch.Size([12673, 736])
# torch.Size([12801, 736])
# torch.Size([12929, 736])
# torch.Size([13057, 736])
# torch.Size([13185, 736])
# torch.Size([13313, 736])
# torch.Size([13441, 736])
# torch.Size([13569, 736])
# torch.Size([13697, 736])
# torch.Size([13825, 736])
# torch.Size([13953, 736])
# torch.Size([14081, 736])
# torch.Size([14209, 736])
# torch.Size([14337, 736])
# torch.Size([14465, 736])
# torch.Size([14593, 736])
# torch.Size([14721, 736])
# torch.Size([14849, 736])
# torch.Size([14977, 736])
# torch.Size([15105, 736])
# torch.Size([15233, 736])
# torch.Size([15361, 736])
# torch.Size([15489, 736])
# torch.Size([15617, 736])
# torch.Size([15745, 736])
# torch.Size([15873, 736])
# torch.Size([16001, 736])
# torch.Size([16129, 736])
# torch.Size([16257, 736])
# torch.Size([16385, 736])
# torch.Size([16513, 736])
# torch.Size([16641, 736])
# torch.Size([16769, 736])
# torch.Size([16897, 736])
# torch.Size([17025, 736])
# torch.Size([17153, 736])
# torch.Size([17281, 736])
# torch.Size([17409, 736])
# torch.Size([17537, 736])
# torch.Size([17665, 736])
# torch.Size([17793, 736])
# torch.Size([17921, 736])
# torch.Size([18049, 736])
# torch.Size([18177, 736])
# torch.Size([18305, 736])
# torch.Size([18433, 736])
# torch.Size([18561, 736])
# torch.Size([18689, 736])
# torch.Size([18817, 736])
# torch.Size([18945, 736])
# torch.Size([19073, 736])
# torch.Size([19201, 736])
# torch.Size([19329, 736])
# torch.Size([19457, 736])
# torch.Size([19585, 736])
# torch.Size([19713, 736])
# torch.Size([19841, 736])
# torch.Size([19969, 736])
# torch.Size([20097, 736])
# torch.Size([20225, 736])
# torch.Size([20353, 736])
# torch.Size([20481, 736])
# torch.Size([20609, 736])
# torch.Size([20737, 736])
# torch.Size([20865, 736])
# torch.Size([20993, 736])
# torch.Size([21121, 736])
# torch.Size([21249, 736])
# torch.Size([21377, 736])
# torch.Size([21505, 736])
# torch.Size([21633, 736])
# torch.Size([21761, 736])
# torch.Size([21889, 736])
# torch.Size([22017, 736])
# torch.Size([22145, 736])
# torch.Size([22273, 736])
# torch.Size([22401, 736])
# torch.Size([22529, 736])
# torch.Size([22657, 736])
# torch.Size([22785, 736])
# torch.Size([22913, 736])
# torch.Size([23041, 736])
# torch.Size([23169, 736])
# torch.Size([23297, 736])
# torch.Size([23425, 736])
# torch.Size([23553, 736])
# torch.Size([23681, 736])
# torch.Size([23809, 736])
# torch.Size([23937, 736])
# torch.Size([24065, 736])
# torch.Size([24193, 736])
# torch.Size([24321, 736])
# torch.Size([24449, 736])
# torch.Size([24577, 736])
# torch.Size([24705, 736])
# torch.Size([24833, 736])
# torch.Size([24961, 736])
# torch.Size([25089, 736])
# torch.Size([25217, 736])
# torch.Size([25345, 736])
# torch.Size([25473, 736])
# torch.Size([25601, 736])
# torch.Size([25729, 736])
# torch.Size([25857, 736])
# torch.Size([25985, 736])
# torch.Size([26113, 736])
# torch.Size([26241, 736])
# torch.Size([26369, 736])
# torch.Size([26497, 736])
# torch.Size([26625, 736])
# torch.Size([26753, 736])
# torch.Size([26881, 736])
# torch.Size([27009, 736])
# torch.Size([27137, 736])
# torch.Size([27265, 736])
# torch.Size([27393, 736])
# torch.Size([27521, 736])
# torch.Size([27649, 736])
# torch.Size([27777, 736])
# torch.Size([27905, 736])
# torch.Size([28033, 736])
# torch.Size([28161, 736])
# torch.Size([28289, 736])
# torch.Size([28417, 736])
# torch.Size([28545, 736])
# torch.Size([28673, 736])
# torch.Size([28801, 736])
# torch.Size([28929, 736])
# torch.Size([29057, 736])
# torch.Size([29185, 736])
# torch.Size([29313, 736])
# torch.Size([29441, 736])
# torch.Size([29569, 736])
# torch.Size([29697, 736])
# torch.Size([29825, 736])
# torch.Size([29953, 736])
# torch.Size([30081, 736])
# torch.Size([30209, 736])
# torch.Size([30337, 736])
# torch.Size([30465, 736])
# torch.Size([30593, 736])
# torch.Size([30721, 736])
# torch.Size([30849, 736])
# torch.Size([30977, 736])
# torch.Size([31105, 736])
# torch.Size([31233, 736])
# torch.Size([31361, 736])
# torch.Size([31489, 736])
# torch.Size([31617, 736])
# torch.Size([31745, 736])
# torch.Size([31873, 736])
# torch.Size([32001, 736])
# torch.Size([32129, 736])
# torch.Size([32257, 736])
# torch.Size([32385, 736])
# torch.Size([32513, 736])
# torch.Size([32641, 736])
# torch.Size([32769, 736])
# torch.Size([32897, 736])
# torch.Size([33025, 736])
# torch.Size([33153, 736])
# torch.Size([33281, 736])
# torch.Size([33409, 736])
# torch.Size([33537, 736])
# torch.Size([33665, 736])
# torch.Size([33793, 736])
# torch.Size([33921, 736])
# torch.Size([34049, 736])
# torch.Size([34177, 736])
# torch.Size([34305, 736])
# torch.Size([34433, 736])
# torch.Size([34561, 736])
# torch.Size([34689, 736])
# torch.Size([34817, 736])
# torch.Size([34945, 736])
# torch.Size([35073, 736])
# torch.Size([35201, 736])
# torch.Size([35329, 736])
# torch.Size([35457, 736])
# torch.Size([35585, 736])
# torch.Size([35713, 736])
# torch.Size([35841, 736])
# torch.Size([35969, 736])
# torch.Size([36097, 736])
# torch.Size([36225, 736])
# torch.Size([36353, 736])
# torch.Size([36481, 736])
# torch.Size([36609, 736])
# torch.Size([36737, 736])
# torch.Size([36865, 736])
# torch.Size([36993, 736])
# torch.Size([37121, 736])
# torch.Size([37249, 736])
# torch.Size([37377, 736])
# torch.Size([37505, 736])
# torch.Size([37633, 736])
# torch.Size([37761, 736])
# torch.Size([37889, 736])
# torch.Size([38017, 736])
# torch.Size([38145, 736])
# torch.Size([38273, 736])
# torch.Size([38401, 736])
# torch.Size([38529, 736])
# torch.Size([38657, 736])
# torch.Size([38785, 736])
# torch.Size([38913, 736])
# torch.Size([39041, 736])
# torch.Size([39169, 736])
# torch.Size([39297, 736])
# torch.Size([39425, 736])
# torch.Size([39553, 736])
# torch.Size([39681, 736])
# torch.Size([39809, 736])
# torch.Size([39937, 736])
# torch.Size([40065, 736])
# torch.Size([40193, 736])
# torch.Size([40321, 736])
# torch.Size([40449, 736])
# torch.Size([40577, 736])
# torch.Size([40705, 736])
# torch.Size([40833, 736])
# torch.Size([40961, 736])
# torch.Size([41089, 736])
# torch.Size([41217, 736])
# torch.Size([41345, 736])
# torch.Size([41473, 736])
# torch.Size([41601, 736])
# torch.Size([41729, 736])
# torch.Size([41857, 736])
# torch.Size([41985, 736])
# torch.Size([42113, 736])
# torch.Size([42241, 736])
# torch.Size([42369, 736])
# torch.Size([42497, 736])
# torch.Size([42625, 736])
# torch.Size([42753, 736])
# torch.Size([42881, 736])
# torch.Size([43009, 736])
# torch.Size([43137, 736])
# torch.Size([43265, 736])
# torch.Size([43393, 736])
# torch.Size([43521, 736])
# torch.Size([43649, 736])
# torch.Size([43777, 736])
# torch.Size([43905, 736])
# torch.Size([44033, 736])
# torch.Size([44161, 736])
# torch.Size([44289, 736])
# torch.Size([44417, 736])
# torch.Size([44545, 736])
# torch.Size([44673, 736])
# torch.Size([44801, 736])
# torch.Size([44929, 736])
# torch.Size([45057, 736])
# torch.Size([45185, 736])
# torch.Size([45313, 736])
# torch.Size([45441, 736])
# torch.Size([45569, 736])
# torch.Size([45697, 736])
# torch.Size([45825, 736])
# torch.Size([45953, 736])
# torch.Size([46081, 736])
# torch.Size([46209, 736])
# torch.Size([46337, 736])
# torch.Size([46465, 736])
# torch.Size([46593, 736])
# torch.Size([46721, 736])
# torch.Size([46849, 736])
# torch.Size([46977, 736])
# torch.Size([47105, 736])
# torch.Size([47233, 736])
# torch.Size([47361, 736])
# torch.Size([47489, 736])
# torch.Size([47617, 736])
# torch.Size([47745, 736])
# torch.Size([47873, 736])
# torch.Size([48001, 736])
# torch.Size([48129, 736])
# torch.Size([48257, 736])
# torch.Size([48385, 736])
# torch.Size([48513, 736])
# torch.Size([48641, 736])
# torch.Size([48769, 736])
# torch.Size([48897, 736])
# torch.Size([49025, 736])
# torch.Size([49153, 736])
# torch.Size([49281, 736])
# torch.Size([49409, 736])
# torch.Size([49537, 736])
# torch.Size([49665, 736])
# torch.Size([49793, 736])
# torch.Size([49921, 736])
# torch.Size([50049, 736])
# torch.Size([50177, 736])
# torch.Size([50305, 736])
# torch.Size([50433, 736])
# torch.Size([50561, 736])
# torch.Size([50689, 736])
# torch.Size([50817, 736])
# torch.Size([50945, 736])
# torch.Size([51073, 736])
# torch.Size([51201, 736])
# torch.Size([51329, 736])
# torch.Size([51457, 736])
# torch.Size([51585, 736])
# torch.Size([51713, 736])
# torch.Size([51841, 736])
# torch.Size([51969, 736])
# torch.Size([52097, 736])
# torch.Size([52225, 736])
# torch.Size([52353, 736])
# torch.Size([52481, 736])
# torch.Size([52609, 736])
# torch.Size([52737, 736])
# torch.Size([52865, 736])
# torch.Size([52993, 736])
# torch.Size([53121, 736])
# torch.Size([53249, 736])
# torch.Size([53377, 736])
# torch.Size([53505, 736])
# torch.Size([53633, 736])
# torch.Size([53761, 736])
# torch.Size([53889, 736])
# torch.Size([54017, 736])
# torch.Size([54145, 736])
# torch.Size([54273, 736])
# torch.Size([54401, 736])
# torch.Size([54529, 736])
# torch.Size([54657, 736])
# torch.Size([54785, 736])
# torch.Size([54913, 736])
# torch.Size([55041, 736])
# torch.Size([55169, 736])
# torch.Size([55297, 736])
# torch.Size([55425, 736])
# torch.Size([55553, 736])
# torch.Size([55681, 736])
# torch.Size([55809, 736])
# torch.Size([55937, 736])
# torch.Size([56065, 736])
# torch.Size([56193, 736])
# torch.Size([56321, 736])
# torch.Size([56449, 736])
# torch.Size([56577, 736])
# torch.Size([56705, 736])
# torch.Size([56833, 736])
# torch.Size([56961, 736])
# torch.Size([57089, 736])
# torch.Size([57217, 736])
# torch.Size([57345, 736])
# torch.Size([57473, 736])
# torch.Size([57601, 736])
# torch.Size([57729, 736])
# torch.Size([57857, 736])
# torch.Size([57985, 736])
# torch.Size([58113, 736])
# torch.Size([58241, 736])
# torch.Size([58369, 736])
# torch.Size([58497, 736])
# torch.Size([58625, 736])
# torch.Size([58753, 736])
# torch.Size([58881, 736])
# torch.Size([59009, 736])
# torch.Size([59137, 736])
# torch.Size([59265, 736])
# torch.Size([59393, 736])
# torch.Size([59521, 736])
# torch.Size([59649, 736])
# torch.Size([59777, 736])
# torch.Size([59905, 736])
# torch.Size([60033, 736])
# torch.Size([60161, 736])
# torch.Size([60289, 736])
# torch.Size([60417, 736])
# torch.Size([60545, 736])
# torch.Size([60673, 736])
# torch.Size([60801, 736])
# torch.Size([60929, 736])
# torch.Size([61057, 736])
# torch.Size([61185, 736])
# torch.Size([61313, 736])
# torch.Size([61441, 736])
# torch.Size([61569, 736])
# torch.Size([61697, 736])
# torch.Size([61825, 736])
# torch.Size([61953, 736])
# torch.Size([62081, 736])
# torch.Size([62209, 736])
# torch.Size([62337, 736])
# torch.Size([62465, 736])
# torch.Size([62593, 736])
# torch.Size([62721, 736])
# torch.Size([62849, 736])
# torch.Size([62977, 736])
# torch.Size([63105, 736])
# torch.Size([63233, 736])
# torch.Size([63361, 736])
# torch.Size([63489, 736])
# torch.Size([63617, 736])
# torch.Size([63745, 736])
# torch.Size([63873, 736])
# torch.Size([64001, 736])
# torch.Size([64129, 736])
# torch.Size([64257, 736])
# torch.Size([64385, 736])
# torch.Size([64513, 736])
# torch.Size([64641, 736])
# torch.Size([64769, 736])
# torch.Size([64897, 736])
# torch.Size([65025, 736])
# torch.Size([65153, 736])
# torch.Size([65281, 736])
# torch.Size([65409, 736])
# torch.Size([65537, 736])
# torch.Size([65665, 736])
# torch.Size([65793, 736])
# torch.Size([65921, 736])
# torch.Size([66049, 736])
# torch.Size([66177, 736])
# torch.Size([66305, 736])
# torch.Size([66433, 736])
# torch.Size([66561, 736])
# torch.Size([66689, 736])
# torch.Size([66817, 736])
# torch.Size([66945, 736])
# torch.Size([67073, 736])
# torch.Size([67201, 736])
# torch.Size([67329, 736])
# torch.Size([67457, 736])
# torch.Size([67585, 736])
# torch.Size([67713, 736])
# torch.Size([67841, 736])
# torch.Size([67969, 736])
# torch.Size([68097, 736])
# torch.Size([68225, 736])
# torch.Size([68353, 736])
# torch.Size([68481, 736])
# torch.Size([68609, 736])
# torch.Size([68737, 736])
# torch.Size([68865, 736])
# torch.Size([68993, 736])
# torch.Size([69121, 736])
# torch.Size([69249, 736])
# torch.Size([69377, 736])
# torch.Size([69505, 736])
# torch.Size([69633, 736])
# torch.Size([69761, 736])
# torch.Size([69889, 736])
# torch.Size([70017, 736])
# torch.Size([70145, 736])
# torch.Size([70273, 736])
# torch.Size([70401, 736])
# torch.Size([70529, 736])
# torch.Size([70657, 736])
# torch.Size([70785, 736])
# torch.Size([70913, 736])
# torch.Size([71041, 736])
# torch.Size([71169, 736])
# torch.Size([71297, 736])
# torch.Size([71425, 736])
# torch.Size([71553, 736])
# torch.Size([71681, 736])
# torch.Size([71809, 736])
# torch.Size([71937, 736])
# torch.Size([72065, 736])
# torch.Size([72193, 736])
# torch.Size([72321, 736])
# torch.Size([72449, 736])
# torch.Size([72577, 736])
# torch.Size([72705, 736])
# torch.Size([72833, 736])
# torch.Size([72961, 736])
# torch.Size([73089, 736])
# torch.Size([73217, 736])
# torch.Size([73345, 736])
# torch.Size([73473, 736])
# torch.Size([73601, 736])
# torch.Size([73729, 736])
# torch.Size([73857, 736])
# torch.Size([73985, 736])
# torch.Size([74113, 736])
# torch.Size([74241, 736])
# torch.Size([74369, 736])
# torch.Size([74497, 736])
# torch.Size([74625, 736])
# torch.Size([74753, 736])
# torch.Size([74881, 736])
# torch.Size([75009, 736])
# torch.Size([75137, 736])
# torch.Size([75265, 736])
# torch.Size([75393, 736])
# torch.Size([75521, 736])
# torch.Size([75649, 736])
# torch.Size([75777, 736])
# torch.Size([75905, 736])
# torch.Size([76033, 736])
# torch.Size([76161, 736])
# torch.Size([76289, 736])
# torch.Size([76417, 736])
# torch.Size([76545, 736])
# torch.Size([76673, 736])
# torch.Size([76801, 736])
# torch.Size([76929, 736])
# torch.Size([77057, 736])
# torch.Size([77185, 736])
# torch.Size([77313, 736])
# torch.Size([77441, 736])
# torch.Size([77569, 736])
# torch.Size([77697, 736])
# torch.Size([77825, 736])
# torch.Size([77953, 736])
# torch.Size([78081, 736])
# torch.Size([78209, 736])
# torch.Size([78337, 736])
# torch.Size([78465, 736])
# torch.Size([78593, 736])
# torch.Size([78721, 736])
# torch.Size([78849, 736])
# torch.Size([78977, 736])
# torch.Size([79105, 736])
# torch.Size([79233, 736])
# torch.Size([79361, 736])
# torch.Size([79489, 736])
# torch.Size([79617, 736])
# torch.Size([79745, 736])
# torch.Size([79873, 736])
# torch.Size([80001, 736])
# torch.Size([80129, 736])
# torch.Size([80257, 736])
# torch.Size([80385, 736])
# torch.Size([80513, 736])
# torch.Size([80641, 736])
# torch.Size([80769, 736])
# torch.Size([80897, 736])
# torch.Size([81025, 736])
# torch.Size([81153, 736])
# torch.Size([81281, 736])
# torch.Size([81409, 736])
# torch.Size([81537, 736])
# torch.Size([81665, 736])
# torch.Size([81793, 736])
# torch.Size([81921, 736])
# torch.Size([82049, 736])
# torch.Size([82177, 736])
# torch.Size([82305, 736])
# torch.Size([82433, 736])
# torch.Size([82561, 736])
# torch.Size([82689, 736])
# torch.Size([82817, 736])
# torch.Size([82945, 736])
# torch.Size([83073, 736])
# torch.Size([83201, 736])
# torch.Size([83329, 736])
# torch.Size([83457, 736])
# torch.Size([83585, 736])
# torch.Size([83713, 736])
# torch.Size([83841, 736])
# torch.Size([83969, 736])
# torch.Size([84097, 736])
# torch.Size([84225, 736])
# torch.Size([84353, 736])
# torch.Size([84481, 736])
# torch.Size([84609, 736])
# torch.Size([84737, 736])
# torch.Size([84865, 736])
# torch.Size([84993, 736])
# torch.Size([85121, 736])
# torch.Size([85249, 736])
# torch.Size([85377, 736])
# torch.Size([85505, 736])
# torch.Size([85633, 736])
# torch.Size([85761, 736])
# torch.Size([85889, 736])
# torch.Size([86017, 736])
# torch.Size([86145, 736])
# torch.Size([86273, 736])
# torch.Size([86401, 736])
# torch.Size([86529, 736])
# torch.Size([86657, 736])
# torch.Size([86785, 736])
# torch.Size([86913, 736])
# torch.Size([87041, 736])
# torch.Size([87169, 736])
# torch.Size([87297, 736])
# torch.Size([87425, 736])
# torch.Size([87553, 736])
# torch.Size([87681, 736])
# torch.Size([87809, 736])
# torch.Size([87937, 736])
# torch.Size([88065, 736])
# torch.Size([88193, 736])
# torch.Size([88321, 736])
# torch.Size([88449, 736])
# torch.Size([88577, 736])
# torch.Size([88705, 736])
# torch.Size([88833, 736])
# torch.Size([88961, 736])
# torch.Size([89089, 736])
# torch.Size([89217, 736])
# torch.Size([89345, 736])
# torch.Size([89473, 736])
# torch.Size([89601, 736])
# torch.Size([89729, 736])
# torch.Size([89857, 736])
# torch.Size([89985, 736])
# torch.Size([90113, 736])
# torch.Size([90241, 736])
# torch.Size([90369, 736])
# torch.Size([90497, 736])
# torch.Size([90625, 736])
# torch.Size([90753, 736])
# torch.Size([90881, 736])
# torch.Size([91009, 736])
# torch.Size([91137, 736])
# torch.Size([91265, 736])
# torch.Size([91393, 736])
# torch.Size([91521, 736])
# torch.Size([91649, 736])
# torch.Size([91777, 736])
# torch.Size([91905, 736])
# torch.Size([92033, 736])
# torch.Size([92161, 736])
# torch.Size([92289, 736])
# torch.Size([92417, 736])
# torch.Size([92545, 736])
# torch.Size([92673, 736])
# torch.Size([92801, 736])
# torch.Size([92929, 736])
# torch.Size([93057, 736])
# torch.Size([93185, 736])
# torch.Size([93313, 736])
# torch.Size([93441, 736])
# torch.Size([93569, 736])
# torch.Size([93697, 736])
# torch.Size([93825, 736])
# torch.Size([93953, 736])
# torch.Size([94081, 736])
# torch.Size([94209, 736])
# torch.Size([94337, 736])
# torch.Size([94465, 736])
# torch.Size([94593, 736])
# torch.Size([94721, 736])
# torch.Size([94849, 736])
# torch.Size([94977, 736])
# torch.Size([95105, 736])
# torch.Size([95233, 736])
# torch.Size([95361, 736])
# torch.Size([95489, 736])
# torch.Size([95617, 736])
# torch.Size([95745, 736])
# torch.Size([95873, 736])
# torch.Size([96001, 736])
# torch.Size([96129, 736])
# torch.Size([96257, 736])
# torch.Size([96385, 736])
# torch.Size([96513, 736])
# torch.Size([96641, 736])
# torch.Size([96769, 736])
# torch.Size([96897, 736])
# torch.Size([97025, 736])
# torch.Size([97153, 736])
# torch.Size([97281, 736])
# torch.Size([97409, 736])
# torch.Size([97537, 736])
# torch.Size([97665, 736])
# torch.Size([97793, 736])
# torch.Size([97921, 736])
# torch.Size([98049, 736])
# torch.Size([98177, 736])
# torch.Size([98305, 736])
# torch.Size([98433, 736])
# torch.Size([98561, 736])
# torch.Size([98689, 736])
# torch.Size([98817, 736])
# torch.Size([98945, 736])
# torch.Size([99073, 736])
# torch.Size([99201, 736])
# torch.Size([99329, 736])
# torch.Size([99457, 736])
# torch.Size([99585, 736])
# torch.Size([99713, 736])
# torch.Size([99841, 736])
# torch.Size([99969, 736])
# torch.Size([100097, 736])
# torch.Size([100225, 736])
# torch.Size([100353, 736])
# torch.Size([100481, 736])
# torch.Size([100609, 736])
# torch.Size([100737, 736])
# torch.Size([100865, 736])
# torch.Size([100993, 736])
# torch.Size([101121, 736])
# torch.Size([101249, 736])
# torch.Size([101377, 736])
# torch.Size([101505, 736])
# torch.Size([101633, 736])
# torch.Size([101761, 736])
# torch.Size([101889, 736])
# torch.Size([102017, 736])
# torch.Size([102145, 736])
# torch.Size([102273, 736])
# torch.Size([102401, 736])
# torch.Size([102529, 736])
# torch.Size([102657, 736])
# torch.Size([102785, 736])
# torch.Size([102913, 736])
# torch.Size([103041, 736])
# torch.Size([103169, 736])
# torch.Size([103297, 736])
# torch.Size([103425, 736])
# torch.Size([103553, 736])
# torch.Size([103681, 736])
# torch.Size([103809, 736])
# torch.Size([103937, 736])
# torch.Size([104065, 736])
# torch.Size([104193, 736])
# torch.Size([104321, 736])
# torch.Size([104449, 736])
# torch.Size([104577, 736])
# torch.Size([104705, 736])
# torch.Size([104833, 736])
# torch.Size([104961, 736])
# torch.Size([105089, 736])
# torch.Size([105217, 736])
# torch.Size([105345, 736])
# torch.Size([105473, 736])
# torch.Size([105601, 736])
# torch.Size([105729, 736])
# torch.Size([105857, 736])
# torch.Size([105985, 736])
# torch.Size([106113, 736])
# torch.Size([106241, 736])
# torch.Size([106369, 736])
# torch.Size([106497, 736])
# torch.Size([106625, 736])
# torch.Size([106753, 736])
# torch.Size([106881, 736])
# torch.Size([107009, 736])
# torch.Size([107137, 736])
# torch.Size([107265, 736])
# torch.Size([107393, 736])
# torch.Size([107521, 736])
# torch.Size([107649, 736])
# torch.Size([107777, 736])
# torch.Size([107905, 736])
# torch.Size([108033, 736])
# torch.Size([108161, 736])
# torch.Size([108289, 736])
# torch.Size([108417, 736])
# torch.Size([108545, 736])
# torch.Size([108673, 736])
# torch.Size([108801, 736])
# torch.Size([108929, 736])
# torch.Size([109057, 736])
# torch.Size([109185, 736])
# torch.Size([109313, 736])
# torch.Size([109441, 736])
# torch.Size([109569, 736])
# torch.Size([109697, 736])
# torch.Size([109825, 736])
# torch.Size([109953, 736])
# torch.Size([110081, 736])
# torch.Size([110209, 736])
# torch.Size([110337, 736])
# torch.Size([110465, 736])
# torch.Size([110593, 736])
# torch.Size([110721, 736])
# torch.Size([110849, 736])
# torch.Size([110977, 736])
# torch.Size([111105, 736])
# torch.Size([111233, 736])
# torch.Size([111361, 736])
# torch.Size([111489, 736])
# torch.Size([111617, 736])
# torch.Size([111745, 736])
# torch.Size([111873, 736])
# torch.Size([112001, 736])
# torch.Size([112129, 736])
# torch.Size([112257, 736])
# torch.Size([112385, 736])
# torch.Size([112513, 736])
# torch.Size([112641, 736])
# torch.Size([112769, 736])
# torch.Size([112897, 736])
# torch.Size([113025, 736])
# torch.Size([113153, 736])
# torch.Size([113281, 736])
# torch.Size([113409, 736])
# torch.Size([113537, 736])
# torch.Size([113665, 736])
# torch.Size([113793, 736])
# torch.Size([113921, 736])
# torch.Size([114049, 736])
# torch.Size([114177, 736])
# torch.Size([114305, 736])
# torch.Size([114433, 736])
# torch.Size([114561, 736])
# torch.Size([114689, 736])
# torch.Size([114817, 736])
# torch.Size([114945, 736])
# torch.Size([115073, 736])
# torch.Size([115201, 736])
# torch.Size([115329, 736])
# torch.Size([115457, 736])
# torch.Size([115585, 736])
# torch.Size([115713, 736])
# torch.Size([115841, 736])
# torch.Size([115969, 736])
# torch.Size([116097, 736])
# torch.Size([116225, 736])
# torch.Size([116353, 736])
# torch.Size([116481, 736])
# torch.Size([116609, 736])
# torch.Size([116737, 736])
# torch.Size([116865, 736])
# torch.Size([116993, 736])
# torch.Size([117121, 736])
# torch.Size([117249, 736])
# torch.Size([117377, 736])
# torch.Size([117505, 736])
# torch.Size([117633, 736])
# torch.Size([117761, 736])
# torch.Size([117889, 736])
# torch.Size([118017, 736])
# torch.Size([118145, 736])
# torch.Size([118273, 736])
# torch.Size([118401, 736])
# torch.Size([118529, 736])
# torch.Size([118657, 736])
# torch.Size([118785, 736])
# torch.Size([118913, 736])
# torch.Size([119041, 736])
# torch.Size([119169, 736])
# torch.Size([119297, 736])
# torch.Size([119425, 736])
# torch.Size([119553, 736])
# torch.Size([119681, 736])
# torch.Size([119809, 736])
# torch.Size([119937, 736])
# torch.Size([120065, 736])
# torch.Size([120193, 736])
# torch.Size([120321, 736])
# torch.Size([120449, 736])
# torch.Size([120577, 736])
# torch.Size([120705, 736])
# torch.Size([120833, 736])
# torch.Size([120961, 736])
# torch.Size([121089, 736])
# torch.Size([121217, 736])
# torch.Size([121345, 736])
# torch.Size([121473, 736])
# torch.Size([121601, 736])
# torch.Size([121729, 736])
# torch.Size([121857, 736])
# torch.Size([121985, 736])
# torch.Size([122113, 736])
# torch.Size([122241, 736])
# torch.Size([122369, 736])
# torch.Size([122497, 736])
# torch.Size([122625, 736])
# torch.Size([122753, 736])
# torch.Size([122881, 736])
# torch.Size([123009, 736])
# torch.Size([123137, 736])
# torch.Size([123265, 736])
# torch.Size([123393, 736])
# torch.Size([123521, 736])
# torch.Size([123649, 736])
# torch.Size([123777, 736])
# torch.Size([123905, 736])
# torch.Size([124033, 736])
# torch.Size([124161, 736])
# torch.Size([124289, 736])
# torch.Size([124417, 736])
# torch.Size([124545, 736])
# torch.Size([124673, 736])
# torch.Size([124801, 736])
# torch.Size([124929, 736])
# torch.Size([125057, 736])
# torch.Size([125185, 736])
# torch.Size([125313, 736])
# torch.Size([125441, 736])
# torch.Size([125569, 736])
# torch.Size([125697, 736])
# torch.Size([125825, 736])
# torch.Size([125953, 736])
# torch.Size([126081, 736])
# torch.Size([126209, 736])
# torch.Size([126337, 736])
# torch.Size([126465, 736])
# torch.Size([126593, 736])
# torch.Size([126721, 736])
# torch.Size([126849, 736])
# torch.Size([126977, 736])
# torch.Size([127105, 736])
# torch.Size([127233, 736])
# torch.Size([127361, 736])
# torch.Size([127489, 736])
# torch.Size([127617, 736])
# torch.Size([127745, 736])
# torch.Size([127873, 736])
# torch.Size([128001, 736])
# torch.Size([128129, 736])
# torch.Size([128257, 736])
# torch.Size([128385, 736])
# torch.Size([128513, 736])
# torch.Size([128641, 736])
# torch.Size([128769, 736])
# torch.Size([128897, 736])
# torch.Size([129025, 736])
# torch.Size([129153, 736])
# torch.Size([129281, 736])
# torch.Size([129409, 736])
# torch.Size([129537, 736])
# torch.Size([129665, 736])
# torch.Size([129793, 736])
# torch.Size([129921, 736])
# torch.Size([130049, 736])
# torch.Size([130177, 736])
# torch.Size([130305, 736])
# torch.Size([130433, 736])
# torch.Size([130561, 736])
# torch.Size([130689, 736])
# torch.Size([130817, 736])
# torch.Size([130945, 736])
# torch.Size([131073, 736])
# torch.Size([131201, 736])
# torch.Size([131329, 736])
# torch.Size([131457, 736])
# torch.Size([131585, 736])
# torch.Size([131713, 736])
# torch.Size([131841, 736])
# torch.Size([131969, 736])
# torch.Size([132097, 736])
# torch.Size([132225, 736])
# torch.Size([132353, 736])
# torch.Size([132481, 736])
# torch.Size([132609, 736])
# torch.Size([132737, 736])
# torch.Size([132865, 736])
# torch.Size([132993, 736])
# torch.Size([133121, 736])
# torch.Size([133249, 736])
# torch.Size([133377, 736])
# torch.Size([133505, 736])
# torch.Size([133633, 736])
# torch.Size([133761, 736])
# torch.Size([133889, 736])
# torch.Size([134017, 736])
# torch.Size([134145, 736])
# torch.Size([134273, 736])
# torch.Size([134401, 736])
# torch.Size([134529, 736])
# torch.Size([134657, 736])
# torch.Size([134785, 736])
# torch.Size([134913, 736])
# torch.Size([135041, 736])
# torch.Size([135169, 736])
# torch.Size([135297, 736])
# torch.Size([135425, 736])
# torch.Size([135553, 736])
# torch.Size([135681, 736])
# torch.Size([135809, 736])
# torch.Size([135937, 736])
# torch.Size([136065, 736])
# torch.Size([136193, 736])
# torch.Size([136321, 736])
# torch.Size([136449, 736])
# torch.Size([136577, 736])
# torch.Size([136705, 736])
# torch.Size([136833, 736])
# torch.Size([136961, 736])
# torch.Size([137089, 736])
# torch.Size([137217, 736])
# torch.Size([137345, 736])
# torch.Size([137473, 736])
# torch.Size([137601, 736])
# torch.Size([137729, 736])
# torch.Size([137857, 736])
# torch.Size([137985, 736])
# torch.Size([138113, 736])
# torch.Size([138241, 736])
# torch.Size([138369, 736])
# torch.Size([138497, 736])
# torch.Size([138625, 736])
# torch.Size([138753, 736])
# torch.Size([138881, 736])
# torch.Size([139009, 736])
# torch.Size([139137, 736])
# torch.Size([139265, 736])
# torch.Size([139393, 736])
# torch.Size([139521, 736])
# torch.Size([139649, 736])
# torch.Size([139777, 736])
# torch.Size([139905, 736])
# torch.Size([140033, 736])
# torch.Size([140161, 736])
# torch.Size([140289, 736])
# torch.Size([140417, 736])
# torch.Size([140545, 736])
# torch.Size([140673, 736])
# torch.Size([140801, 736])
# torch.Size([140929, 736])
# torch.Size([141057, 736])
# torch.Size([141185, 736])
# torch.Size([141313, 736])
# torch.Size([141441, 736])
# torch.Size([141569, 736])
# torch.Size([141697, 736])
# torch.Size([141825, 736])
# torch.Size([141953, 736])
# torch.Size([142081, 736])
# torch.Size([142209, 736])
# torch.Size([142337, 736])
# torch.Size([142465, 736])
# torch.Size([142593, 736])
# torch.Size([142721, 736])
# torch.Size([142849, 736])
# torch.Size([142977, 736])
# torch.Size([143105, 736])
# torch.Size([143233, 736])
# torch.Size([143361, 736])
# torch.Size([143489, 736])
# torch.Size([143617, 736])
# torch.Size([143745, 736])
# torch.Size([143873, 736])
# torch.Size([144001, 736])
# torch.Size([144129, 736])
# torch.Size([144257, 736])
# torch.Size([144385, 736])
# torch.Size([144513, 736])
# torch.Size([144641, 736])
# torch.Size([144769, 736])
# torch.Size([144897, 736])
# torch.Size([145025, 736])
# torch.Size([145153, 736])
# torch.Size([145281, 736])
# torch.Size([145409, 736])
# torch.Size([145537, 736])
# torch.Size([145665, 736])
# torch.Size([145793, 736])
# torch.Size([145921, 736])
# torch.Size([146049, 736])
# torch.Size([146177, 736])
# torch.Size([146305, 736])
# torch.Size([146433, 736])
# torch.Size([146561, 736])
# torch.Size([146689, 736])
# torch.Size([146817, 736])
# torch.Size([146945, 736])
# torch.Size([147073, 736])
# torch.Size([147201, 736])
# torch.Size([147329, 736])
# torch.Size([147457, 736])
# torch.Size([147585, 736])
# torch.Size([147713, 736])
# torch.Size([147841, 736])
# torch.Size([147969, 736])
# torch.Size([148097, 736])
# torch.Size([148225, 736])
# torch.Size([148353, 736])
# torch.Size([148481, 736])
# torch.Size([148609, 736])
# torch.Size([148737, 736])
# torch.Size([148865, 736])
# torch.Size([148993, 736])
# torch.Size([149121, 736])
# torch.Size([149249, 736])
# torch.Size([149377, 736])
# torch.Size([149505, 736])
# torch.Size([149633, 736])
# torch.Size([149761, 736])
# torch.Size([149889, 736])
# torch.Size([150017, 736])
# torch.Size([150145, 736])
# torch.Size([150273, 736])
# torch.Size([150401, 736])
# torch.Size([150529, 736])
# torch.Size([150657, 736])
# torch.Size([150785, 736])
# torch.Size([150913, 736])
# torch.Size([151041, 736])
# torch.Size([151169, 736])
# torch.Size([151297, 736])
# torch.Size([151425, 736])
# torch.Size([151553, 736])
# torch.Size([151681, 736])
# torch.Size([151809, 736])
# torch.Size([151937, 736])
# torch.Size([152065, 736])
# torch.Size([152193, 736])
# torch.Size([152321, 736])
# torch.Size([152449, 736])
# torch.Size([152577, 736])
# torch.Size([152705, 736])
# torch.Size([152833, 736])
# torch.Size([152961, 736])
# torch.Size([153089, 736])
# torch.Size([153217, 736])
# torch.Size([153345, 736])
# torch.Size([153473, 736])
# torch.Size([153601, 736])
# torch.Size([153729, 736])
# torch.Size([153857, 736])
# torch.Size([153985, 736])
# torch.Size([154113, 736])
# torch.Size([154241, 736])
# torch.Size([154369, 736])
# torch.Size([154497, 736])
# torch.Size([154625, 736])
# torch.Size([154753, 736])
# torch.Size([154881, 736])
# torch.Size([155009, 736])
# torch.Size([155137, 736])
# torch.Size([155265, 736])
# torch.Size([155393, 736])
# torch.Size([155521, 736])
# torch.Size([155649, 736])
# torch.Size([155777, 736])
# torch.Size([155905, 736])
# torch.Size([156033, 736])
# torch.Size([156161, 736])
# torch.Size([156289, 736])
# torch.Size([156417, 736])
# torch.Size([156545, 736])
# torch.Size([156673, 736])
# torch.Size([156801, 736])
# torch.Size([156929, 736])
# torch.Size([157057, 736])
# torch.Size([157185, 736])
# torch.Size([157313, 736])
# torch.Size([157441, 736])
# torch.Size([157569, 736])
# torch.Size([157697, 736])
# torch.Size([157825, 736])
# torch.Size([157953, 736])
# torch.Size([158081, 736])
# torch.Size([158209, 736])
# torch.Size([158337, 736])
# torch.Size([158465, 736])
# torch.Size([158593, 736])
# torch.Size([158721, 736])
# torch.Size([158849, 736])
# torch.Size([158977, 736])
# torch.Size([159105, 736])
# torch.Size([159233, 736])
# torch.Size([159361, 736])
# torch.Size([159489, 736])
# torch.Size([159617, 736])
# torch.Size([159745, 736])
# torch.Size([159873, 736])
# torch.Size([160001, 736])
# torch.Size([160129, 736])
# torch.Size([160257, 736])
# torch.Size([160385, 736])
# torch.Size([160513, 736])
# torch.Size([160641, 736])
# torch.Size([160769, 736])
# torch.Size([160897, 736])
# torch.Size([161025, 736])
# torch.Size([161153, 736])
# torch.Size([161281, 736])
# torch.Size([161409, 736])
# torch.Size([161537, 736])
# torch.Size([161665, 736])
# torch.Size([161793, 736])
# torch.Size([161921, 736])
# torch.Size([162049, 736])
# torch.Size([162177, 736])
# torch.Size([162305, 736])
# torch.Size([162433, 736])
# torch.Size([162561, 736])
# torch.Size([162689, 736])
# torch.Size([162817, 736])
# torch.Size([162945, 736])
# torch.Size([163073, 736])
# torch.Size([163201, 736])
# torch.Size([163329, 736])
# torch.Size([163457, 736])
# torch.Size([163585, 736])
# torch.Size([163713, 736])
# torch.Size([163841, 736])
# torch.Size([163969, 736])
# torch.Size([164097, 736])
# torch.Size([164225, 736])
# torch.Size([164353, 736])
# torch.Size([164481, 736])
# torch.Size([164609, 736])
# torch.Size([164737, 736])
# torch.Size([164865, 736])
# torch.Size([164993, 736])
# torch.Size([165121, 736])
# torch.Size([165249, 736])
# torch.Size([165377, 736])
# torch.Size([165505, 736])
# torch.Size([165633, 736])
# torch.Size([165761, 736])
# torch.Size([165889, 736])
# torch.Size([166017, 736])
# torch.Size([166145, 736])
# torch.Size([166273, 736])
# torch.Size([166401, 736])
# torch.Size([166529, 736])
# torch.Size([166657, 736])
# torch.Size([166785, 736])
# torch.Size([166913, 736])
# torch.Size([167041, 736])
# torch.Size([167169, 736])
# torch.Size([167297, 736])
# torch.Size([167425, 736])
# torch.Size([167553, 736])
# torch.Size([167681, 736])
# torch.Size([167809, 736])
# torch.Size([167937, 736])
# torch.Size([168065, 736])
# torch.Size([168193, 736])
# torch.Size([168321, 736])
# torch.Size([168449, 736])
# torch.Size([168577, 736])
# torch.Size([168705, 736])
# torch.Size([168833, 736])
# torch.Size([168961, 736])
# torch.Size([169089, 736])
# torch.Size([169217, 736])
# torch.Size([169345, 736])
# torch.Size([169473, 736])
# torch.Size([169601, 736])
# torch.Size([169729, 736])
# torch.Size([169857, 736])
# torch.Size([169985, 736])
# torch.Size([170113, 736])
# torch.Size([170241, 736])
# torch.Size([170369, 736])
# torch.Size([170497, 736])
# torch.Size([170625, 736])
# torch.Size([170753, 736])
# torch.Size([170881, 736])
# torch.Size([171009, 736])
# torch.Size([171137, 736])
# torch.Size([171265, 736])
# torch.Size([171393, 736])
# torch.Size([171521, 736])
# torch.Size([171649, 736])
# torch.Size([171777, 736])
# torch.Size([171905, 736])
# torch.Size([172033, 736])
# torch.Size([172161, 736])
# torch.Size([172289, 736])
# torch.Size([172417, 736])
# torch.Size([172545, 736])
# torch.Size([172673, 736])
# torch.Size([172801, 736])
# torch.Size([172929, 736])
# torch.Size([173057, 736])
# torch.Size([173185, 736])
# torch.Size([173313, 736])
# torch.Size([173441, 736])
# torch.Size([173569, 736])
# torch.Size([173697, 736])
# torch.Size([173825, 736])
# torch.Size([173953, 736])
# torch.Size([174081, 736])
# torch.Size([174209, 736])
# torch.Size([174337, 736])
# torch.Size([174465, 736])
# torch.Size([174593, 736])
# torch.Size([174721, 736])
# torch.Size([174849, 736])
# torch.Size([174977, 736])
# torch.Size([175105, 736])
# torch.Size([175233, 736])
# torch.Size([175361, 736])
# torch.Size([175489, 736])
# torch.Size([175617, 736])
# torch.Size([175745, 736])
# torch.Size([175873, 736])
# torch.Size([176001, 736])
# torch.Size([176129, 736])
# torch.Size([176257, 736])
# torch.Size([176385, 736])
# torch.Size([176513, 736])
# torch.Size([176641, 736])
# torch.Size([176769, 736])
# torch.Size([176897, 736])
# torch.Size([177025, 736])
# torch.Size([177153, 736])
# torch.Size([177281, 736])
# torch.Size([177409, 736])
# torch.Size([177537, 736])
# torch.Size([177665, 736])
# torch.Size([177793, 736])
# torch.Size([177921, 736])
# torch.Size([178049, 736])
# torch.Size([178177, 736])
# torch.Size([178305, 736])
# torch.Size([178433, 736])
# torch.Size([178561, 736])
# torch.Size([178689, 736])
# torch.Size([178817, 736])
# torch.Size([178945, 736])
# torch.Size([179073, 736])
# torch.Size([179201, 736])
# torch.Size([179329, 736])
# torch.Size([179457, 736])
# torch.Size([179585, 736])
# torch.Size([179713, 736])
# torch.Size([179841, 736])
# torch.Size([179969, 736])
# torch.Size([180097, 736])
# torch.Size([180225, 736])
# torch.Size([180353, 736])
# torch.Size([180481, 736])
# torch.Size([180609, 736])
# torch.Size([180737, 736])
# torch.Size([180865, 736])
# torch.Size([180993, 736])
# torch.Size([181121, 736])
# torch.Size([181249, 736])
# torch.Size([181377, 736])
# torch.Size([181505, 736])
# torch.Size([181633, 736])
# torch.Size([181761, 736])
# torch.Size([181889, 736])
# torch.Size([182017, 736])
# torch.Size([182145, 736])
# torch.Size([182273, 736])
# torch.Size([182401, 736])
# torch.Size([182529, 736])
# torch.Size([182657, 736])
# torch.Size([182785, 736])
# torch.Size([182913, 736])
# torch.Size([183041, 736])
# torch.Size([183169, 736])
# torch.Size([183297, 736])
# torch.Size([183425, 736])
# torch.Size([183553, 736])
# torch.Size([183681, 736])
# torch.Size([183809, 736])
# torch.Size([183937, 736])
# torch.Size([184065, 736])
# torch.Size([184193, 736])
# torch.Size([184321, 736])
# torch.Size([184449, 736])
# torch.Size([184577, 736])
# torch.Size([184705, 736])
# torch.Size([184833, 736])
# torch.Size([184961, 736])
# torch.Size([185089, 736])
# torch.Size([185217, 736])
# torch.Size([185345, 736])
# torch.Size([185473, 736])
# torch.Size([185601, 736])
# torch.Size([185729, 736])
# torch.Size([185857, 736])
# torch.Size([185985, 736])
# torch.Size([186113, 736])
# torch.Size([186241, 736])
# torch.Size([186369, 736])
# torch.Size([186497, 736])
# torch.Size([186625, 736])
# torch.Size([186753, 736])
# torch.Size([186881, 736])
# torch.Size([187009, 736])
# torch.Size([187137, 736])
# torch.Size([187265, 736])
# torch.Size([187393, 736])
# torch.Size([187521, 736])
# torch.Size([187649, 736])
# torch.Size([187777, 736])
# torch.Size([187905, 736])
# torch.Size([188033, 736])
# torch.Size([188161, 736])
# torch.Size([188289, 736])
# torch.Size([188417, 736])
# torch.Size([188545, 736])
# torch.Size([188673, 736])
# torch.Size([188801, 736])
# torch.Size([188929, 736])
# torch.Size([189057, 736])
# torch.Size([189185, 736])
# torch.Size([189313, 736])
# torch.Size([189441, 736])
# torch.Size([189569, 736])
# torch.Size([189697, 736])
# torch.Size([189825, 736])
# torch.Size([189953, 736])
# torch.Size([190081, 736])
# torch.Size([190209, 736])
# torch.Size([190337, 736])
# torch.Size([190465, 736])
# torch.Size([190593, 736])
# torch.Size([190721, 736])
# torch.Size([190849, 736])
# torch.Size([190977, 736])
# torch.Size([191105, 736])
# torch.Size([191233, 736])
# torch.Size([191361, 736])
# torch.Size([191489, 736])
# torch.Size([191617, 736])
# torch.Size([191745, 736])
# torch.Size([191873, 736])
# torch.Size([192001, 736])
# torch.Size([192129, 736])
# torch.Size([192257, 736])
# torch.Size([192385, 736])
# torch.Size([192513, 736])
# torch.Size([192641, 736])
# torch.Size([192769, 736])
# torch.Size([192897, 736])
# torch.Size([193025, 736])
# torch.Size([193153, 736])
# torch.Size([193281, 736])
# torch.Size([193409, 736])
# torch.Size([193537, 736])
# torch.Size([193665, 736])
# torch.Size([193793, 736])
# torch.Size([193921, 736])
# torch.Size([194049, 736])
# torch.Size([194177, 736])
# torch.Size([194305, 736])
# torch.Size([194433, 736])
# torch.Size([194561, 736])
# torch.Size([194689, 736])
# torch.Size([194817, 736])
# torch.Size([194945, 736])
# torch.Size([195073, 736])
# torch.Size([195201, 736])
# torch.Size([195329, 736])
# torch.Size([195457, 736])
# torch.Size([195585, 736])
# torch.Size([195713, 736])
# torch.Size([195841, 736])
# torch.Size([195969, 736])
# torch.Size([196097, 736])
# torch.Size([196225, 736])
# torch.Size([196353, 736])
# torch.Size([196481, 736])
# torch.Size([196609, 736])
# torch.Size([196673, 736])

# %%
image_features = image_features[1:, :]
torch.save(image_features, outf + 'image_features.pth')

# %%
image_features.shape
# Out:
# torch.Size([196672, 736])
